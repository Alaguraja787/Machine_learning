# %%
import cv2
import numpy as np

# %%
cv2.__version__
# Out:
# '4.13.0'

# %%
img = cv2.imread("/content/virat & anushka.jpg")

# %%
img
# Out:
# array([[[119,  96, 104],
#         [119,  96, 104],
#         [119,  96, 104],
#         ...,
#         [ 97,  80,  84],
#         [ 96,  79,  83],
#         [ 95,  78,  82]],
#
#        [[127, 104, 112],
#         [127, 104, 112],
#         [128, 105, 113],
#         ...,
#         [100,  83,  87],
#         [ 99,  82,  86],
#         [ 99,  82,  86]],
#
#        [[137, 113, 123],
#         [137, 113, 123],
#         [138, 114, 124],
#         ...,
#         [106,  88,  95],
#         [105,  87,  94],
#         [105,  87,  94]],
#
#        ...,
#
#        [[  7,   4, 183],
#         [  7,   4, 183],
#         [  8,   3, 184],
#         ...,
#         [ 73,  83, 117],
#         [ 67,  84, 127],
#         [ 75,  95, 142]],
#
#        [[  7,   5, 181],
#         [  7,   5, 181],
#         [  8,   4, 183],
#         ...,
#         [ 77,  87, 121],
#         [ 74,  91, 134],
#         [ 85, 105, 152]],
#
#        [[  8,   5, 181],
#         [  8,   5, 181],
#         [ 10,   4, 183],
# ...

# %%
img1 = cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=168x299>

# %%
cv2.imwrite('via.jpg', img)
# Out:
# True

# %%
img.size
# Out:
# 150696

# %%
img.shape
# Out:
# (299, 168, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img2 =img[30:150,40:150]

# %%
img2
# Out:
# array([[[108,  82, 100],
#         [108,  82, 100],
#         [108,  82, 100],
#         ...,
#         [105,  82, 104],
#         [105,  82, 104],
#         [104,  81, 103]],
#
#        [[108,  82, 100],
#         [108,  82, 100],
#         [108,  82, 100],
#         ...,
#         [105,  82, 104],
#         [105,  82, 104],
#         [104,  81, 103]],
#
#        [[112,  86, 102],
#         [112,  86, 102],
#         [112,  86, 102],
#         ...,
#         [105,  83, 102],
#         [105,  83, 102],
#         [104,  82, 101]],
#
#        ...,
#
#        [[ 77, 121, 204],
#         [ 71, 114, 193],
#         [ 61, 104, 177],
#         ...,
#         [ 95,  90, 121],
#         [ 93,  87, 118],
#         [ 93,  85, 115]],
#
#        [[ 88, 120, 195],
#         [ 84, 116, 189],
#         [ 78, 109, 178],
#         ...,
#         [ 85,  86, 120],
#         [ 86,  85, 119],
#         [ 88,  85, 117]],
#
#        [[ 91, 122, 191],
#         [ 93, 118, 188],
#         [ 91, 114, 182],
# ...

# %%
img3 = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=299x168>

# %%
img2 = cv2.flip(img,-1)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=168x299>

# %%
img3 = cv2.resize(img,(300,500))
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=300x500>

# %%
img1 = cv2.blur(img,(1,10))
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=168x299>
