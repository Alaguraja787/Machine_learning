# %%
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
 df = pd.read_csv("/content/IMDB Dataset.csv", engine='python', quotechar='"')

# %%
df["sentiment"] = df["sentiment"].map({
    "positive":1,
    "negative":0
})

# %%
df = df.sample(10000, random_state=42)

# %%
X = df["review"]
y = df["sentiment"]

# %%
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(X)

X_seq = tokenizer.texts_to_sequences(X)

# %%
X_pad = pad_sequences(
    X_seq,
    maxlen=200,
    padding='post'
)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_pad,
    y,
    test_size=0.2,
    random_state=42
)

vocab_size = 10000

# %% [markdown]
# ###**LSTM**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense

model = Sequential([
    Embedding(vocab_size, 128),

    LSTM(64),

    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()

history = model.fit(
    X_train,
    y_train,
    epochs=15,
    batch_size=64,
    validation_data=(X_test,y_test)
)
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 31s 230ms/step - accuracy: 0.5390 - loss: 0.6909 - val_accuracy: 0.6330 - val_loss: 0.6622
# Epoch 2/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 29s 230ms/step - accuracy: 0.6186 - loss: 0.6397 - val_accuracy: 0.5930 - val_loss: 0.6398
# Epoch 3/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 235ms/step - accuracy: 0.6445 - loss: 0.5621 - val_accuracy: 0.6025 - val_loss: 0.6306
# Epoch 4/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 29s 229ms/step - accuracy: 0.6842 - loss: 0.5375 - val_accuracy: 0.5835 - val_loss: 0.6473
# Epoch 5/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 28s 225ms/step - accuracy: 0.7163 - loss: 0.4928 - val_accuracy: 0.5940 - val_loss: 0.6465
# Epoch 6/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 28s 226ms/step - accuracy: 0.7411 - loss: 0.5022 - val_accuracy: 0.7730 - val_loss: 0.5437
# Epoch 7/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 29s 233ms/step - accuracy: 0.8698 - loss: 0.3220 - val_accuracy: 0.8155 - val_loss: 0.4526
# Epoch 8/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 30s 239ms/step - accuracy: 0.9016 - loss: 0.2532 - val_accuracy: 0.8195 - val_loss: 0.4405
# Epoch 9/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 29s 228ms/step - accuracy: 0.9365 - loss: 0.1848 - val_accuracy: 0.8305 - val_loss: 0.4473
# Epoch 10/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 42s 233ms/step - accuracy: 0.9597 - loss: 0.1300 - val_accuracy: 0.8365 - val_loss: 0.4566
# Epoch 11/15
#  22/125 ━━━━━━━━━━━━━━━━━━━━ 26s 259ms/step - accuracy: 0.9789 - loss: 0.0702
