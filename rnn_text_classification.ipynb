# %%
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
df = pd.read_csv("/content/IMDB Dataset.csv", engine='python', quotechar='"')

# %%
df["sentiment"] = df["sentiment"].map({
    "positive":1,
    "negative":0
})

# %%
df = df.sample(10000, random_state=42)

# %%
X = df["review"]
y = df["sentiment"]

# %%
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(X)
X_seq = tokenizer.texts_to_sequences(X)

# %%
X_pad = pad_sequences(
    X_seq,
    maxlen=200,
    padding='post'
)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_pad,
    y,
    test_size=0.2,
    random_state=42
)

# %%
vocab_size = 10000

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import SimpleRNN
from tensorflow.keras.layers import Dense

model = Sequential([
    Embedding(vocab_size, 128),

    SimpleRNN(64),

    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()

history = model.fit(
    X_train,
    y_train,
    epochs=15,
    batch_size=64,
    validation_data=(X_test,y_test)
)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 93ms/step - accuracy: 0.5141 - loss: 0.6947 - val_accuracy: 0.5200 - val_loss: 0.6905
# Epoch 2/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 91ms/step - accuracy: 0.6334 - loss: 0.6411 - val_accuracy: 0.5090 - val_loss: 0.6984
# Epoch 3/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 86ms/step - accuracy: 0.7091 - loss: 0.4981 - val_accuracy: 0.5205 - val_loss: 0.7416
# Epoch 4/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 85ms/step - accuracy: 0.7426 - loss: 0.4081 - val_accuracy: 0.5240 - val_loss: 0.8000
# Epoch 5/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 12s 98ms/step - accuracy: 0.7598 - loss: 0.3810 - val_accuracy: 0.5160 - val_loss: 0.8291
# Epoch 6/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 12s 97ms/step - accuracy: 0.7605 - loss: 0.3745 - val_accuracy: 0.5150 - val_loss: 0.8514
# Epoch 7/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 20s 92ms/step - accuracy: 0.7809 - loss: 0.3510 - val_accuracy: 0.5335 - val_loss: 0.8820
# Epoch 8/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 90ms/step - accuracy: 0.7901 - loss: 0.3446 - val_accuracy: 0.5060 - val_loss: 0.9505
# Epoch 9/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 88ms/step - accuracy: 0.7803 - loss: 0.3539 - val_accuracy: 0.5245 - val_loss: 0.9821
# Epoch 10/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 84ms/step - accuracy: 0.8041 - loss: 0.3246 - val_accuracy: 0.5265 - val_loss: 0.9389
# Epoch 11/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 21s 91ms/step - accuracy: 0.8215 - loss: 0.3097 - val_accuracy: 0.5225 - val_loss: 0.9345
# Epoch 12/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 91ms/step - accuracy: 0.8084 - loss: 0.3238 - val_accuracy: 0.5245 - val_loss: 1.0379
# Epoch 13/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 12s 92ms/step - accuracy: 0.7919 - loss: 0.3623 - val_accuracy: 0.5400 - val_loss: 0.9756
# Epoch 14/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 92ms/step - accuracy: 0.8133 - loss: 0.3122 - val_accuracy: 0.5265 - val_loss: 1.1064
# Epoch 15/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 11s 87ms/step - accuracy: 0.8006 - loss: 0.3283 - val_accuracy: 0.5350 - val_loss: 1.0215
