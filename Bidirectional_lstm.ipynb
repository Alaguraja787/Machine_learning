# %%
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
df = pd.read_csv("/content/IMDB Dataset.csv", engine='python', quotechar='"')

# %%
df["sentiment"] = df["sentiment"].map({
    "positive":1,
    "negative":0
})

# %%
df = df.sample(10000, random_state=42)

# %%
X = df["review"]
y = df["sentiment"]

# %%
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(X)

X_seq = tokenizer.texts_to_sequences(X)

# %%
X_pad = pad_sequences(
    X_seq,
    maxlen=200,
    padding='post'
)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_pad,
    y,
    test_size=0.2,
    random_state=42
)

vocab_size = 10000

# %% [markdown]
# ###**BI-DIRECTIONAL**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.layers import Dense

model = Sequential([
    Embedding(vocab_size, 128),

    Bidirectional(
        LSTM(64)
    ),

    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()

history = model.fit(
    X_train,
    y_train,
    epochs=15,
    batch_size=64,
    validation_data=(X_test,y_test)
)
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 64s 478ms/step - accuracy: 0.6420 - loss: 0.6306 - val_accuracy: 0.7845 - val_loss: 0.4847
# Epoch 2/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 84s 498ms/step - accuracy: 0.8250 - loss: 0.4126 - val_accuracy: 0.8155 - val_loss: 0.4345
# Epoch 3/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 80s 483ms/step - accuracy: 0.9026 - loss: 0.2504 - val_accuracy: 0.8300 - val_loss: 0.3926
# Epoch 4/15
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 62s 500ms/step - accuracy: 0.9517 - loss: 0.1447 - val_accuracy: 0.8450 - val_loss: 0.4313
# Epoch 5/15
#  71/125 ━━━━━━━━━━━━━━━━━━━━ 24s 456ms/step - accuracy: 0.9740 - loss: 0.0794
