# %%
import cv2
import numpy as np

# %%
img = cv2.imread("/content/WhatsApp Image 2025-06-08 at 7.32.46 PM.jpeg")

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(gray_image, 50,100)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=1600x943>

# %%
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=1600x943>
